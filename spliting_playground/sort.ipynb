# %%
import polib

def sort_po_file(po_file_path):
    # Open the PO file
    po = polib.pofile(po_file_path)

    # Sort the entries by msgid
    po_entries_sorted = sorted(po, key=lambda entry: entry.msgid)

    # Save the sorted entries to a new PO file
    po_sorted = polib.POFile()
    po_sorted.metadata = po.metadata
    po_sorted.extend(po_entries_sorted)
    po_sorted.save(po_file_path)

# glob every po file in the './translated' folder or subfolder and sort them
    
import glob

for po_file_path in glob.glob('./translated/**/*.po', recursive=True):
    print('Sorting ' + po_file_path)
    sort_po_file(po_file_path)
# Out:
# Sorting ./translated/categories/code_bits.po
# Sorting ./translated/categories/linting_messages.po
# Sorting ./translated/categories/frontend.po
# Sorting ./translated/categories/misc_terms.po
# Sorting ./translated/categories/chapters.po
# Sorting ./translated/categories/output_predictions.po
# Sorting ./translated/pages/22_BuildingNewLists.po
# Sorting ./translated/pages/25_CallingFunctionsTerminology.po
# Sorting ./translated/pages/12_BuildingUpStringsExercises.po
# Sorting ./translated/pages/35_IntroducingNestedLoops.po
# Sorting ./translated/pages/20_OtherComparisonOperators.po
# Sorting ./translated/pages/19_IntroducingElif.po
# Sorting ./translated/pages/7_StoringCalculationsInVariables.po
# Sorting ./translated/pages/47_CombiningAndAndOr.po
# Sorting ./translated/pages/46_MultiLineExpressions.po
# Sorting ./translated/pages/38_LoopingOverNestedLists.po
# Sorting ./translated/pages/52_InteractiveProgramsWithInput.po
# Sorting ./translated/pages/28_StringMethodsUnderstandingMutation.po
# Sorting ./translated/pages/2_IntroducingStrings.po
# Sorting ./translated/pages/51_Types.po
# Sorting ./translated/pages/31_EqualsVsIs.po
# Sorting ./translated/pages/21_IntroducingLists.po
# Sorting ./translated/pages/58_IntroducingDictionaries.po
# Sorting ./translated/pages/34_IntroducingFstrings.po
# Sorting ./translated/pages/27_MoreListFunctionsAndMethods.po
# Sorting ./translated/pages/56_GettingElementsAtPositionExercises.po
# Sorting ./translated/pages/14_IntroducingIfStatements.po
# Sorting ./translated/pages/11_BuildingUpStrings.po
# Sorting ./translated/pages/41_ReturningValuesFromFunctions.po
# Sorting ./translated/pages/48_IntroducingNotPage.po
# Sorting ./translated/pages/9_Indentation.po
# Sorting ./translated/pages/55_TheFullTicTacToeGame.po
# Sorting ./translated/pages/3_AddingStrings.po
# Sorting ./translated/pages/30_UnderstandingProgramsWithPythonTutor.po
# Sorting ./translated/pages/5_UsingVariables.po
# Sorting ./translated/pages/57_DictionaryKeysAndValues.po
# Sorting ./translated/pages/40_CallingFunctionsWithinFunctions.po
# Sorting ./translated/pages/26_FunctionsAndMethodsForLists.po
# Sorting ./translated/pages/49_IntroducingTicTacToe.po
# Sorting ./translated/pages/43_MoreOnReturn.po
# Sorting ./translated/pages/13_BasicTerminology.po
# Sorting ./translated/pages/50_NewlinesAndFormatBoard.po
# Sorting ./translated/pages/59_UsingDictionaries.po
# Sorting ./translated/pages/23_UsingBreak.po
# Sorting ./translated/pages/33_SingleAndDoubleQuotesInStrings.po
# Sorting ./translated/pages/15_CombiningCompoundStatements.po
# Sorting ./translated/pages/53_NestedListAssignment.po
# Sorting ./translated/pages/36_IntroducingBirdseye.po
# Sorting ./translated/pages/0_IntroducingTheShell.po
# Sorting ./translated/pages/4_IntroducingVariables.po
# Sorting ./translated/pages/37_IntroducingNestedLists.po
# Sorting ./translated/pages/39_DefiningFunctions.po
# Sorting ./translated/pages/17_IfAndElse.po
# Sorting ./translated/pages/42_TestingFunctions.po
# Sorting ./translated/pages/18_TheEqualityOperator.po
# Sorting ./translated/pages/8_IntroducingForLoops.po
# Sorting ./translated/pages/29_HowToFindInformationWithGoogleAndMore.po
# Sorting ./translated/pages/45_IntroducingAnd.po
# Sorting ./translated/pages/10_BasicForLoopExercises.po
# Sorting ./translated/pages/6_WritingPrograms.po
# Sorting ./translated/pages/54_MakingTheBoard.po
# Sorting ./translated/pages/44_IntroducingOr.po
# Sorting ./translated/pages/16_UnderstandingProgramsWithSnoop.po
# Sorting ./translated/pages/24_GettingElementsAtPosition.po
# Sorting ./translated/pages/1_NavigatingShellHistory.po
# Sorting ./translated/pages/32_ModifyingWhileIterating.po
