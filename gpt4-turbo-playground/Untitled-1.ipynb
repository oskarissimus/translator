# %%
from openai import OpenAI
import pofile

def translate(text, dry_run=False):
    if dry_run:
        return text
    client = OpenAI()
    response = client.chat.completions.create(
        model="gpt-4-1106-preview",
        messages=[
            {"role": "system", "content": "translate to polish"},
            {"role": "user", "content": contents},
        ],
    )
    return response.choices[0].message.content

input_file = "./futurecoder_English.po"
# take first 100 entries from the file
entries = pofile
# Out:
# msgid "pages.IntroducingTheShell.steps.first_expression.text"
# msgstr "On the right is the *shell*. This is a place for running small bits of Python code. Just type in some code, press enter, and it'll run! Try it now:\n"
# "\n"
# "1. Click anywhere on the shell (the black area).\n"
# "2. Type `__program__`\n"
# "3. Press the Enter key on your keyboard."
# msgid "pages.IntroducingTheShell.steps.more_calculation.text"
# msgstr "Great! Python evaluated `1+2` and got the result `3`, so the shell displays that.\n"
# "\n"
# "The shell is probably your most important tool for learning Python, and you should spend lots of time experimenting and exploring in it. Be curious! Constantly ask yourself \"What would happen if I ran X?\" and then immediately answer that question by running it. Never be scared to try something out - if you get something wrong, nothing bad will happen.\n"
# "\n"
# "Try doing some more calculations now. You can multiply numbers with `*`, divide with `/`, and subtract with `-`. You can also use parentheses, i.e. `(` and `)`."
# msgid "pages.IntroducingTheShell.steps.final_text.text"
# msgstr "Excellent! Keep experimenting. When you're ready, click 'Next' to continue."
# msgid "pages.NavigatingShellHistory.steps.final_text.text"
# msgstr "Here's a tip: often you will want to re-run a previously entered bit of code, or a slightly modified version of it. You can copy and paste, but that's tedious and gets in the way of experimenting. A better method is to press the Up Arrow key on your keyboard. This will insert the previous line of code into the shell. Keep pressing it to go further back in your history, and if you go too far, press the Down Arrow key to go the other way. Try using it now."
# msgid "pages.IntroducingStrings.steps.hello_string.text"
# msgstr "Python lets you do much more than calculate. In fact, we're not going to touch numbers or maths for a while. Instead, we're going to look at *strings*. Strings are essentially snippets of text. For example, enter the following into the shell, quotes (`'`) included:\n"
# "\n"
# "__program_indented__"
# msgid "pages.IntroducingStrings.steps.final_text.text"
# msgstr "The shell simply gives the same thing back because there's nothing further to calculate. `'hello'` is simply equal to `'hello'`.\n"
# "\n"
# "A string is a sequence of characters. A character is a single symbol such as a letter, number, punctuation, space, etc. In this case the string contains the 5 characters `hello`. The quotes are not part of the string - they are there to tell both humans and computers that this is a string consisting of whatever characters are between the quotes."
# msgid "pages.AddingStrings.steps.hello_world_concat.text"
# msgstr "Strings can be added together using `+`, although this means something very different from adding numbers. For example, try:\n"
# "\n"
# "__program_indented__"
# msgid "pages.AddingStrings.steps.hello_world_space.text"
# msgstr "You can see that `+` combines or joins two strings together end to end. Technically, this is called concatenation.\n"
# "\n"
# "Here's an exercise: change the previous code slightly so that the result is the string `'hello world'`, i.e. with a space between the words.\n"
# "\n"
# "By the way, if you get stuck, you can click the lightbulb icon in the bottom right for a hint."
# msgid "pages.AddingStrings.steps.final_text.text"
# msgstr "Well done! Any of the following are valid solutions:\n"
# "\n"
# "__code0__"
# msgid "pages.IntroducingVariables.steps.word_assign.text"
# msgstr "To make interesting programs, we can't always manipulate the same values. We need a way to refer to values that are unknown ahead of time and can change - values that can vary. These are called *variables*.\n"
# "\n"
# "Run this code:\n"
# "\n"
# "__program_indented__"
# msgid "pages.IntroducingVariables.steps.word_check.text"
# msgstr "This creates a variable with the name `word` that refers to the string value `'Hello'`.\n"
# "\n"
# "Now see what happens when you run `__program__` in the shell by itself."
# msgid "pages.IntroducingVariables.steps.word_string_check.text"
# msgstr "Good. For comparison, run `__program__` in the shell by itself, with the quotes."
# msgid "pages.IntroducingVariables.steps.sunshine_undefined_check.text"
# msgstr "As you can see, the quotes make all the difference. `'word'` is literally just `'word'`, hence it's technically called a *string literal*. On the other hand, `word` is a variable, whose value may be anything.\n"
# "\n"
# "Similarly, `'sunshine'` is `'sunshine'`, but what's `__program__` without quotes?"
# msgid "pages.IntroducingVariables.steps.final_text.text"
# msgstr "The answer is that `sunshine` looks like a variable, so Python tries to look up its value, but since we never defined a variable with that name we get an error."
# msgid "pages.UsingVariables.steps.name_assign.text"
# msgstr "Previously we made a variable called `word` with the value `'Hello'` with this code:\n"
# "\n"
# "__code0__\n"
# "\n"
# "Now make a variable called `your_name` whose value is another string.\n"
# "\n"
# "(The character `_` in `your_name` is called an *underscore*. Use it to separate words when you want a variable name containing multiple words. You can type it on most keyboards by pressing Shift and hyphen/dash/minus (`-`).)"
# msgid "pages.UsingVariables.steps.hello_plus_name.text"
# msgstr "You can use variables in calculations just like you would use literals. For example, try:\n"
# "\n"
# "__program_indented__"
# msgid "pages.UsingVariables.steps.word_plus_name.text"
# msgstr "Or you can just add variables together. Try:\n"
# "\n"
# "__code0__"
# msgid "pages.UsingVariables.steps.word_plus_name_with_space.text"
# msgstr "Oops...that doesn't look nice. Can you modify the code above so that there's a space between the word and your name?"
# msgid "pages.UsingVariables.steps.word_assign_goodbye.text"
# msgstr "Perfect!\n"
# "\n"
# "Variables can also change their values over time. Right now `word` has the value `'Hello'`. You can change its value in the same way that you set it for the first time. Run this:\n"
# "\n"
# "__code0__"
# msgid "pages.UsingVariables.steps.goodbye_plus_name.text"
# msgstr "Now observe the effect of this change by running `__program__` again."
# msgid "pages.UsingVariables.steps.first_print.text"
# msgstr "Those quotes around strings are getting annoying. Try running this:\n"
# "\n"
# "__code0__"
# msgid "pages.UsingVariables.steps.final_text.text"
# msgstr "Hooray! No more quotes! We'll break down what's happening in this code later. For now just know that `print(<something>)` displays `<something>` in the shell. In particular it displays the actual content of strings that we usually care about, instead of a representation of strings that's suitable for code which has things like quotes. The word `print` here has nothing to do with putting ink on paper."
# msgid "pages.WritingPrograms.steps.editor_hello_world.text"
# msgstr "It's time to stop doing everything in the shell. In the top right you can see the *editor*. This is a place where you can write and run longer programs. The shell is great and you should keep using it to explore, but the editor is where real programs live.\n"
# "\n"
# "Type the program below into the editor, then click the 'Run' button:\n"
# "\n"
# "__code0__"
# msgid "pages.WritingPrograms.steps.final_text.text"
# msgstr "Congratulations, you have run your first actual program!\n"
# "\n"
# "Take some time to understand this program. Python runs each line one at a time from top to bottom. You should try simulating this process in your head - think about what each line does. See how the value of `word` was changed and what effect this had. Note that when `print` is used multiple times, each thing (`Hello World` and `Goodbye World` in this case) is printed on its own line.\n"
# "\n"
# "Some things to note about programs in the editor:\n"
# ChatCompletion(id='chatcmpl-8LvPKB96n9G0Y0nJjo8IzxUdDXZqo', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='msgid "pages.IntroducingTheShell.steps.first_expression.text"\nmsgstr "Po prawej znajduje się *shell*. Jest to miejsce do uruchamiania małych fragmentów kodu Python. Wpisz po prostu jakiś kod, naciśnij enter i kod się wykona! Spróbuj teraz:\\n"\n"\\n"\n"1. Kliknij gdziekolwiek na shell (czarny obszar).\\n"\n"2. Wpisz `__program__`\\n"\n"3. Naciśnij klawisz Enter na klawiaturze."\nmsgid "pages.IntroducingTheShell.steps.more_calculation.text"\nmsgstr "Świetnie! Python ocenił `1+2` i otrzymał wynik `3`, więc shell wyświetla to.\\n"\n"\\n"\n"Shell jest prawdopodobnie twoim najważniejszym narzędziem do nauki Pythona i powinieneś spędzić dużo czasu na eksperymentowaniu i odkrywaniu w nim różnych możliwości. Bądź ciekawy! Ciągle zadawaj sobie pytanie \\"Co by się stało, gdybym uruchomił X?\\" i natychmiast odpowiadaj na to pytanie, próbując to uruchomić. Nigdy nie bój się spróbować czegoś nowego - jeśli coś zrobisz źle, nic złego się nie stanie.\\n"\n"\\n"\n"Spróbuj teraz wykonać kilka dodatkowych obliczeń. Możesz mnożyć liczby za pomocą `*`, dzielić za pomocą `/` i odejmować za pomocą `-`. Możesz także używać nawiasów, czyli `(` i `)`."\nmsgid "pages.IntroducingTheShell.steps.final_text.text"\nmsgstr "Doskonale! Kontynuuj eksperymentowanie. Kiedy będziesz gotowy, kliknij \'Dalej\', aby kontynuować."\nmsgid "pages.NavigatingShellHistory.steps.final_text.text"\nmsgstr "Oto wskazówka: często będziesz chciał uruchomić ponownie wcześniej wprowadzony fragment kodu lub jego nieco zmodyfikowaną wersję. Możesz skopiować i wkleić, ale to uciążliwe i przeszkadza w eksperymentowaniu. Lepszą metodą jest naciśnięcie klawisza strzałki w górę na klawiaturze. Spowoduje to wstawienie poprzedniej linii kodu do shella. Naciskaj go, aby cofać dalej w historii, a jeśli przejdziesz za daleko, naciśnij strzałkę w dół, aby iść w drugą stronę. Spróbuj teraz użyć tej funkcji."\nmsgid "pages.IntroducingStrings.steps.hello_string.text"\nmsgstr "Python pozwala zrobić o wiele więcej niż tylko obliczenia. W rzeczywistości nie będziemy dotykać liczb ani matematyki przez jakiś czas. Zamiast tego przyjrzymy się *łańcuchom znaków* (stringom). Stringi to w zasadzie fragmenty tekstu. Na przykład wprowadź poniższe do shella, wraz z cudzysłowami (`\'`):\\n"\n"\\n"\n"__program_indented__"\nmsgid "pages.IntroducingStrings.steps.final_text.text"\nmsgstr "Shell po prostu zwraca to samo, ponieważ nie ma dalszych obliczeń do wykonania. `\'hello\'` jest po prostu równe `\'hello\'`.\\n"\n"\\n"\n"String jest sekwencją znaków. Znak to pojedynczy symbol, taki jak litera, liczba, znak interpunkcyjny, spacja itp. W tym przypadku string zawiera 5 znaków `hello`. Cudzysłowia nie są częścią stringa - są one tam, aby informować zarówno ludzi, jak i komputery, że jest to string składający się z dowolnych znaków pomiędzy cudzysłowiami."\nmsgid "pages.AddingStrings.steps.hello_world_concat.text"\nmsgstr "Stringi można dodawać do siebie za pomocą `+`, chociaż oznacza to coś zupełnie innego niż dodawanie liczb. Na przykład spróbuj:\\n"\n"\\n"\n"__program_indented__"\nmsgid "pages.AddingStrings.steps.hello_world_space.text"\nmsgstr "Widać, że `+` łączy dwa stringi ze sobą, koniec do końca. Technicznie nazywa się to konkatenacją.\\n"\n"\\n"\n"Oto ćwiczenie: zmień nieco poprzedni kod, aby wynikiem był string `\'hello world\'`, czyli z odstępem między słowami.\\n"\n"\\n"\n"Przy okazji, jeśli utkniesz, możesz kliknąć ikonę żarówki w prawym dolnym rogu, aby uzyskać podpowiedź."\nmsgid "pages.AddingStrings.steps.final_text.text"\nmsgstr "Dobra robota! Wszystkie z poniższych są prawidłowymi rozwiązaniami:\\n"\n"\\n"\n"__code0__"\nmsgid "pages.IntroducingVariables.steps.word_assign.text"\nmsgstr "Aby tworzyć interesujące programy, nie możemy zawsze manipulować tymi samymi wartościami. Potrzebujemy sposobu, aby odnosić się do wartości, które nie są znane z gór ...

# %%
print(response.choices[0].message.content)
# Out:
# msgid "pages.IntroducingTheShell.steps.first_expression.text"
# msgstr "Po prawej znajduje się *shell*. Jest to miejsce do uruchamiania małych fragmentów kodu Python. Wpisz po prostu jakiś kod, naciśnij enter i kod się wykona! Spróbuj teraz:\n"
# "\n"
# "1. Kliknij gdziekolwiek na shell (czarny obszar).\n"
# "2. Wpisz `__program__`\n"
# "3. Naciśnij klawisz Enter na klawiaturze."
# msgid "pages.IntroducingTheShell.steps.more_calculation.text"
# msgstr "Świetnie! Python ocenił `1+2` i otrzymał wynik `3`, więc shell wyświetla to.\n"
# "\n"
# "Shell jest prawdopodobnie twoim najważniejszym narzędziem do nauki Pythona i powinieneś spędzić dużo czasu na eksperymentowaniu i odkrywaniu w nim różnych możliwości. Bądź ciekawy! Ciągle zadawaj sobie pytanie \"Co by się stało, gdybym uruchomił X?\" i natychmiast odpowiadaj na to pytanie, próbując to uruchomić. Nigdy nie bój się spróbować czegoś nowego - jeśli coś zrobisz źle, nic złego się nie stanie.\n"
# "\n"
# "Spróbuj teraz wykonać kilka dodatkowych obliczeń. Możesz mnożyć liczby za pomocą `*`, dzielić za pomocą `/` i odejmować za pomocą `-`. Możesz także używać nawiasów, czyli `(` i `)`."
# msgid "pages.IntroducingTheShell.steps.final_text.text"
# msgstr "Doskonale! Kontynuuj eksperymentowanie. Kiedy będziesz gotowy, kliknij 'Dalej', aby kontynuować."
# msgid "pages.NavigatingShellHistory.steps.final_text.text"
# msgstr "Oto wskazówka: często będziesz chciał uruchomić ponownie wcześniej wprowadzony fragment kodu lub jego nieco zmodyfikowaną wersję. Możesz skopiować i wkleić, ale to uciążliwe i przeszkadza w eksperymentowaniu. Lepszą metodą jest naciśnięcie klawisza strzałki w górę na klawiaturze. Spowoduje to wstawienie poprzedniej linii kodu do shella. Naciskaj go, aby cofać dalej w historii, a jeśli przejdziesz za daleko, naciśnij strzałkę w dół, aby iść w drugą stronę. Spróbuj teraz użyć tej funkcji."
# msgid "pages.IntroducingStrings.steps.hello_string.text"
# msgstr "Python pozwala zrobić o wiele więcej niż tylko obliczenia. W rzeczywistości nie będziemy dotykać liczb ani matematyki przez jakiś czas. Zamiast tego przyjrzymy się *łańcuchom znaków* (stringom). Stringi to w zasadzie fragmenty tekstu. Na przykład wprowadź poniższe do shella, wraz z cudzysłowami (`'`):\n"
# "\n"
# "__program_indented__"
# msgid "pages.IntroducingStrings.steps.final_text.text"
# msgstr "Shell po prostu zwraca to samo, ponieważ nie ma dalszych obliczeń do wykonania. `'hello'` jest po prostu równe `'hello'`.\n"
# "\n"
# "String jest sekwencją znaków. Znak to pojedynczy symbol, taki jak litera, liczba, znak interpunkcyjny, spacja itp. W tym przypadku string zawiera 5 znaków `hello`. Cudzysłowia nie są częścią stringa - są one tam, aby informować zarówno ludzi, jak i komputery, że jest to string składający się z dowolnych znaków pomiędzy cudzysłowiami."
# msgid "pages.AddingStrings.steps.hello_world_concat.text"
# msgstr "Stringi można dodawać do siebie za pomocą `+`, chociaż oznacza to coś zupełnie innego niż dodawanie liczb. Na przykład spróbuj:\n"
# "\n"
# "__program_indented__"
# msgid "pages.AddingStrings.steps.hello_world_space.text"
# msgstr "Widać, że `+` łączy dwa stringi ze sobą, koniec do końca. Technicznie nazywa się to konkatenacją.\n"
# "\n"
# "Oto ćwiczenie: zmień nieco poprzedni kod, aby wynikiem był string `'hello world'`, czyli z odstępem między słowami.\n"
# "\n"
# "Przy okazji, jeśli utkniesz, możesz kliknąć ikonę żarówki w prawym dolnym rogu, aby uzyskać podpowiedź."
# msgid "pages.AddingStrings.steps.final_text.text"
# msgstr "Dobra robota! Wszystkie z poniższych są prawidłowymi rozwiązaniami:\n"
# "\n"
# "__code0__"
# msgid "pages.IntroducingVariables.steps.word_assign.text"
# msgstr "Aby tworzyć interesujące programy, nie możemy zawsze manipulować tymi samymi wartościami. Potrzebujemy sposobu, aby odnosić się do wartości, które nie są znane z góry i mogą się zmieniać - wartości, które mogą zmieniać się. Są to tzw. *zmienne*.\n"
# "\n"
# "Uruchom ten kod:\n"
# "\n"
# "__program_indented__"
# msgid "pages.IntroducingVariables.steps.word_check.text"
# msgstr "Tworzy to zmienną o nazwie `word` odnoszącą się do wartości stringowej `'Hello'`.\n"
# "\n"
# "Teraz zobacz, co się stanie, gdy uruchomisz `__program__` w shellu samodzielnie."
# msgid "pages.IntroducingVariables.steps.word_string_check.text"
# msgstr "Dobrze. Dla porównania, uruchom `__program__` w shellu samodzielnie, z cudzysłowami."
# msgid "pages.IntroducingVariables.steps.sunshine_undefined_check.text"
# msgstr "Jak widać, cudzysłowia robią całą różnicę. `'word'` jest dosłownie tylko `'word'`, stąd technicznie nazywane jest to *literałem stringowym*. Z drugiej strony, `word` to zmienna, której wartość może być dowolna.\n"
# "\n"
# "Podobnie, `'sunshine'` to `'sunshine'`, ale co to jest `__program__` bez cudzysłowów?"
# msgid "pages.IntroducingVariables.steps.final_text.text"
# msgstr "Odpowiedź brzmi, że `sunshine` wygląda na zmienną, więc Python próbuje odnaleźć jej wartość, ale ponieważ nigdy nie zdefiniowaliśmy zmiennej o tej nazwie, otrzymujemy błąd."
# msgid "pages.UsingVariables.steps.name_assign.text"
# msgstr "Wcześniej stworzyliśmy zmienną o nazwie `word` z wartością `'Hello'` za pomocą tego kodu:\n"
# "\n"
# "__code0__\n"
# "\n"
# "Teraz stwórz zmienną o nazwie `your_name`, której wartością będzie inny string.\n"
# "\n"
# "(Znak `_` w `your_name` to *podkreślenie*. Używa się go do oddzielania słów, gdy chcesz zawrzeć wiele słów w nazwie zmiennej. Możesz go wpisać na większości klawiatur naciskając Shift i myślnik/dash/minus (`-`).)"
# msgid "pages.UsingVariables.steps.hello_plus_name.text"
# msgstr "Możesz używać zmiennych w obliczeniach tak samo jak używałbyś literałów. Na przykład spróbuj:\n"
# "\n"
# "__program_indented__"
# msgid "pages.UsingVariables.steps.word_plus_name.text"
# msgstr "Lub możesz po prostu dodać zmienne do siebie. Spróbuj:\n"
# "\n"
# "__code0__"
# msgid "pages.UsingVariables.steps.word_plus_name_with_space.text"
# msgstr "Ups... to nie wygląda ładnie. Czy możesz zmodyfikować powyższy kod tak, aby był odstęp między słowem a twoim imieniem?"
# msgid "pages.UsingVariables.steps.word_assign_goodbye.text"
# msgstr "Doskonale!\n"
# "\n"
# "Zmienne również mogą zmieniać swoje wartości z czasem. Obecnie `word` ma wartość `'Hello'`. Możesz zmienić jej wartość w ten sam sposób, w jaki ustawiłeś ją po raz pierwszy. Uruchom to:\n"
# "\n"
# "__code0__"
# msgid "pages.UsingVariables.steps.goodbye_plus_name.text"
# msgstr "Teraz zaobserwuj efekt tej zmiany, uruchamiając `__program__` ponownie."
# msgid "pages.UsingVariables.steps.first_print.text"
# msgstr "Te cudzysłowia wokół stringów stają się irytujące. Spróbuj uruchomić to:\n"
# "\n"
# "__code0__"
# msgid "pages.UsingVariables.steps.final_text.text"
# msgstr "Hura! Nie ma więcej cudzysłowów! Omówimy dokładniej, co dzieje się w tym kodzie później. Na razie wystarczy wiedzieć, że `print(<something>)` wyświetla `<something>` w shellu. W szczególności pokazuje faktyczną zawartość stringów, o które nam zazwyczaj chodzi, zamiast reprezentacji stringów, która nadaje się do kodu i zawiera takie rzeczy jak cudzysłowia. Słowo `print` tutaj nie ma nic wspólnego z umieszczaniem tuszu na papierze."
# msgid "pages.WritingPrograms.steps.editor_hello_world.text"
# msgstr "Nadszedł czas, aby przestać robić wszystko w shellu. W prawym górnym rogu możesz zobaczyć *edytor*. To miejsce, gdzie możesz pisać i uruchamiać dłuższe programy. Shell jest świetny i powinieneś go nadal używać do eksploracji, ale to w edytorze mieszkać będą prawdziwe programy.\n"
# "\n"
# "Wpisz poniższy program do edytora, a następnie kliknij przycisk 'Run' (Uruchom):\n"
# "\n"
# "__code0__"
# msgid "pages.WritingPrograms.steps.final_text.text"
# msgstr "Gratulacje, uruchomiłeś swój pierwszy prawdziwy program!\n"
# "\n"
# "Poświęć chwilę, aby zrozumieć ten program. Python wykonuje każdą linię jeden po drugim, od góry do dołu. Powinieneś spróbować symulować ten proces w swojej głowie - pomyśleć o tym, co robi każda linia. Zobacz, jak wartość `word` została zmieniona i jaki miało to wpływ. Zwróć uwagę, że kiedy używa się `print` wielokrotnie, każda rzecz (w tym przypadku `Hello World` i `Goodbye World`) jest drukowana na własnej linii.\n"
# "\n"
# "Kilka uwag na temat programów w edytorze:\n"

# %%
(response.choices[0].message.content)
# Out:
# ChatCompletion(id='chatcmpl-8LvKfkP3DLYfUxdRZqvIhD2SxjeG0', choices=[Choice(finish_reason='stop', index=0, message=ChatCompletionMessage(content='Twoje rozwiązanie jest prawidłowe! Jednak dla tego ćwiczenia i Twojej nauki, nie wolno Ci używać tej etykiety {disallowed_default_label}.', role='assistant', function_call=None, tool_calls=None))], created=1700235965, model='gpt-4-1106-preview', object='chat.completion', system_fingerprint='fp_a24b4d720c', usage=CompletionUsage(completion_tokens=44, prompt_tokens=82495, total_tokens=82539))
